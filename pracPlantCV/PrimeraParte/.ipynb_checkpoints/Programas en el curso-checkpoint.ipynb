# %% [markdown]
# # PROGRAMAS EN EL CURSO
#
#
# ## Python
#
# Python es un lenguaje de programación que permite programar e integrar los sistemas creados con mayor rapidez.
#
#
# [python program](https://www.python.org)
#
#
# ## NumPy
#
# NumPy es es la librería básica de cálculo matemático de Python.
#
#
# https://numpy.org
#
#
# ## Pandas
# Pandas es una herramienta rápida, flexible y fácil de usar para el análisis y manipulación de datos.
#
#
# https://pandas.pydata.org
#
#
# ## matplotlib
#
# Matplotlib es una librería para crear visualizaciones estáticas, animadas e interactivas de Python.
#
# https://matplotlib.org
#
#
# ## Pillow
#  es una librería para la edición de imágenes.
#
#
# https://pypi.org/project/Pillow/
#
#
# ## Collections
# Este módulo implementa contenedores especializados de datos
#
# https://docs.python.org/3/library/collections.html
#
# ## PlantCV
# Sistema para el análisis de imágenes de plantas.
#
# https://plantcv.readthedocs.io/en/stable/
#
# ## OpenCV-Python
# Es una librería de Python diseñada para solucionar problemas de visión computacional
#
# https://pypi.org/project/opencv-python/
#
# ## scikit-image
# scikit proveé de un conjunto de rutinas para el análisis de imágenes basado en scipy.ndimage
#
# ## mahotas
# Mahotas es una librería de visión computacional y proceso de imágenes para python
#
# https://mahotas.readthedocs.io/en/latest/
#
#
# ## Jupyter
#
# El proyecto Jupyter existe para desarrollar programas "open-source", "open-standards, y servicios para el cálculo interactivo mediante deiversos lenguajes de programación
#
# https://jupyter.org
