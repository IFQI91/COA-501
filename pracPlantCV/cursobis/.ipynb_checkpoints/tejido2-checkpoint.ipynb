# %% [markdown]
# # Identificación de estructuras en tejidos vegetales

# %%
import cv2
import numpy as np

from plantcv import plantcv as pcv

# %%
# Input image into self.image (include file path if image is not in 
# the same folder as jupyter notebook)

# Set self.debug to "plot" so that image outputs for each step is shown
# once cell is run in jupyter notebooks (recommended)

class options:
    def __init__(self):        
        self.image = "./tejido2.png"
        self.debug = "plot"
        self.writeimg = False
        self.result = "seed_analysis_results"
        self.outdir = "."

# %%
# Get options
args = options()

# Set debug to the global parameter
pcv.params.debug = args.debug

# %%
# Inputs:
#   filename = Image file to be read in 
#   mode     = How to read in the image; either 'native' (default), 'rgb', 'gray', or 'csv'
img, path, filename = pcv.readimage(filename=args.image)

# %%
# Inputs:
#   rbg_img      = original image
#   original_img = whether to include the original RGB images in the display: True (default) or False
colorspace_img = pcv.visualize.colorspaces(rgb_img=img)

# %%
# Inputs:
#   rbg_img - original image
#   channel - desired colorspace 
h_img = pcv.rgb2gray_hsv(rgb_img=img, channel='h')

# %%
#h_median=pcv.median_blur(h_img,5)

# %%
h_thresh=pcv.threshold.binary(gray_img=h_img, threshold=50, max_value=150, object_type='dark')

# %%
h_fill=pcv.fill(h_thresh,500)

# %%
h_median=pcv.median_blur(h_fill,3)

# %%
### Se definen umbrales

# Inputs:
#   gray_img    = black and white image created from selected colorspace
#   threshold   = cutoff pixel intensity value (all pixels below value will become black, all above will become white)
#   max_value   = maximum pixel value
#   object_type = 'dark' or 'light' depending on if seeds are darker or lighter than background
h_thresh = pcv.threshold.binary(gray_img=xor_img, threshold=120, max_value=150, object_type='dark')

# %%
h_erode=pcv.erode(h_thresh,ksize=7,i=1)

# %%
h_fill=pcv.fill(h_erode,500)

# %%
# Inputs:
#   rbg_img - original image
#   channel - desired colorspace 
v_img = pcv.rgb2gray_hsv(rgb_img=img, channel='v')

# %%
### Se definen umbrales

# Inputs:
#   gray_img    = black and white image created from selected colorspace
#   threshold   = cutoff pixel intensity value (all pixels below value will become black, all above will become white)
#   max_value   = maximum pixel value
#   object_type = 'dark' or 'light' depending on if seeds are darker or lighter than background
v_thresh = pcv.threshold.binary(gray_img=v_img, threshold=125, max_value=125, object_type='dark')

# %%
# Inputs:
#   rbg_img - original image
#   channel - desired colorspace 
b_img = pcv.rgb2gray_lab(rgb_img=img, channel='b')

# %%
xor_img=pcv.logical_and(h_img,b_img)

# %%
### Se definen umbrales

# Inputs:
#   gray_img    = black and white image created from selected colorspace
#   threshold   = cutoff pixel intensity value (all pixels below value will become black, all above will become white)
#   max_value   = maximum pixel value
#   object_type = 'dark' or 'light' depending on if seeds are darker or lighter than background
hb_thresh = pcv.threshold.binary(gray_img=xor_img, threshold=125, max_value=150, object_type='light')

# %%
hb_fill=pcv.fill(hb_thresh,500)

# %%
hb_erode=pcv.erode(hb_fill,ksize=5,i=1)

# %%
hb_fill=pcv.fill(hb_erode,500)

# %%
hb_fill_holes=pcv.fill_holes(hb_fill)

# %%
hb_dilate=pcv.dilate(hb_fill_holes,ksize=5,i=1)

# %%
v_thresh=pcv.threshold.binary(gray_img=v_img, threshold=180, max_value=250, object_type='light')

# %%
v_fill_holes=pcv.fill_holes(v_thresh)

# %%
v_median_blur=pcv.median_blur(v_fill_holes,5)

# %%
b_thresh=pcv.threshold.binary(gray_img=b_img, threshold=107, max_value=110, object_type='dark')

# %%
b_fill_holes=pcv.fill_holes(b_thresh)

# %%
b_median_blur=pcv.median_blur(b_fill_holes,3)
